# %%
# provides a simple API to write functional/acceptance tests using Selenium WebDriver
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
import time
import pandas as pd

# %%
def get_jobs(keyword, num_jobs, verbose, path, slep_time):
    
    '''Gathers jobs as a dataframe, scraped from Glassdoor'''
    
    #Initializing the webdriver
    options = webdriver.ChromeOptions()
    
    #Uncomment the line below if you'd like to scrape without a new Chrome window every time.
    #options.add_argument('headless')
    
    #Change the path to where chromedriver is in your home folder.
    driver = webdriver.Chrome(executable_path=path, options=options)
    driver.set_window_size(1120, 1000)
    url = "https://www.glassdoor.ca/Job/jobs.htm?suggestCount=0&suggestChosen=false&clickSource=searchBtn&typedKeyword="+keyword+"&sc.keyword="+keyword+"&locT=&locId=&jobType="
    #url = 'https://www.glassdoor.ca/Job/canada-jobs.htm?sc.keyword="' + keyword + '"&locT=C&locId=1147401&locKeyword=San%20Francisco,%20CA&jobType=all&fromAge=-1&minSalary=0&includeNoSalaryJobs=true&radius=100&cityId=-1&minRating=0.0&industryId=-1&sgocId=-1&seniorityType=all&companyId=-1&employerSizes=0&applicationType=0&remoteWorkType=0'
    driver.get(url) #website to script data 
    jobs = []

    while len(jobs) < num_jobs:  #If true, should be still looking for new jobs.

        #Let the page load. Change this number based on your internet speed.
        #Or, wait until the webpage is loaded, instead of hardcoding it.
        time.sleep(slep_time)

        #Test for the "Sign Up" prompt and get rid of it.
        try:
            driver.find_element_by_class_name("selected").click()
        except ElementClickInterceptedException:
            pass

        time.sleep(.1)

        try:
            driver.find_element_by_css_selector('[alt="Close"]').click()  #clicking to the X.
        except NoSuchElementException:
            pass

        
        #Going through each job in this page
        job_buttons = driver.find_elements_by_class_name("jl")  #jl for Job Listing. These are the buttons we're going to click.
        for job_button in job_buttons:  

            print("Progress: {}".format("" + str(len(jobs)) + "/" + str(num_jobs)))
            if len(jobs) >= num_jobs:
                break

            job_button.click()  #You might 
            time.sleep(1)
            collected_successfully = False
            
            while not collected_successfully:
                try:
                    company_name = driver.find_element_by_xpath('.//div[@class="employerName"]').text
                    location = driver.find_element_by_xpath('.//div[@class="location"]').text
                    job_title = driver.find_element_by_xpath('.//div[contains(@class, "title")]').text
                    
                    job_description = driver.find_element_by_xpath('.//div[@class="jobDescriptionContent desc"]').text
                    collected_successfully = True
                except:
                    time.sleep(5)

            try:
                salary_estimate = driver.find_element_by_xpath('.//span[@class="gray salary"]').text
            except NoSuchElementException:
                salary_estimate = -1 #You need to set a "not found value. It's important."
            try:
                rating = driver.find_element_by_xpath('.//span[@class="rating"]').text
            except NoSuchElementException:
                rating = -1 #You need to set a "not found value. It's important."

            #Printing for debugging
            if verbose:
                print("Job Title: {}".format(job_title))
                print("Salary Estimate: {}".format(salary_estimate))
                print("Job Description: {}".format(job_description[:500]))
                print("Rating: {}".format(rating))
                print("Company Name: {}".format(company_name))
                print("Location: {}".format(location))

            #Going to the Company tab...
            #clicking on this:
            #<div class="tab" data-tab-type="overview"><span>Company</span></div>
            try:
                driver.find_element_by_xpath('.//div[@class="tab" and @data-tab-type="overview"]').click()

                try:
                    #<div class="infoEntity">
                    #    <label>Headquarters</label>
                    #    <span class="value">San Francisco, CA</span>
                    #</div>
                    headquarters = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Headquarters"]//following-sibling::*').text
                except NoSuchElementException:
                    headquarters = -1

                try:
                    size = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Size"]//following-sibling::*').text
                except NoSuchElementException:
                    size = -1

                try:
                    founded = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Founded"]//following-sibling::*').text
                except NoSuchElementException:
                    founded = -1

                try:
                    type_of_ownership = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Type"]//following-sibling::*').text
                except NoSuchElementException:
                    type_of_ownership = -1

                try:
                    industry = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Industry"]//following-sibling::*').text
                except NoSuchElementException:
                    industry = -1

                try:
                    sector = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Sector"]//following-sibling::*').text
                except NoSuchElementException:
                    sector = -1

                try:
                    revenue = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Revenue"]//following-sibling::*').text
                except NoSuchElementException:
                    revenue = -1

                try:
                    competitors = driver.find_element_by_xpath('.//div[@class="infoEntity"]//label[text()="Competitors"]//following-sibling::*').text
                except NoSuchElementException:
                    competitors = -1
                    
            except NoSuchElementException:  #Rarely, some job postings do not have the "Company" tab.
                headquarters = -1
                size = -1
                founded = -1
                type_of_ownership = -1
                industry = -1
                sector = -1
                revenue = -1
                competitors = -1

                
            if verbose:
                print("Headquarters: {}".format(headquarters))
                print("Size: {}".format(size))
                print("Founded: {}".format(founded))
                print("Type of Ownership: {}".format(type_of_ownership))
                print("Industry: {}".format(industry))
                print("Sector: {}".format(sector))
                print("Revenue: {}".format(revenue))
                print("Competitors: {}".format(competitors))
                print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")

            jobs.append({"Job Title" : job_title,
            "Salary Estimate" : salary_estimate,
            "Job Description" : job_description,
            "Rating" : rating,
            "Company Name" : company_name,
            "Location" : location,
            "Headquarters" : headquarters,
            "Size" : size,
            "Founded" : founded,
            "Type of ownership" : type_of_ownership,
            "Industry" : industry,
            "Sector" : sector,
            "Revenue" : revenue,
            "Competitors" : competitors})
            #add job to jobs

        #Clicking on the "next page" button
        try:
            driver.find_element_by_xpath('.//li[@class="next"]//a').click()
        except NoSuchElementException:
            print("Scraping terminated before reaching target number of jobs. Needed {}, got {}.".format(num_jobs, len(jobs)))
            break

    return pd.DataFrame(jobs)  #This line converts the dictionary object into a pandas DataFrame.

# %%
path = "/Users/lizha/Documents/ds_project/chromedriver"
df= get_jobs('data analyst',30,False,path,15)
# Out:
# Progress: 0/30
# Progress: 1/30
# Progress: 2/30
# Progress: 3/30
# Progress: 4/30
# Progress: 5/30
# Progress: 6/30
# Progress: 7/30
# Progress: 8/30
# Progress: 9/30
# Progress: 10/30
# Progress: 11/30
# Progress: 12/30
# Progress: 13/30
# Progress: 14/30
# Progress: 15/30
# Progress: 16/30
# Progress: 17/30
# Progress: 18/30
# Progress: 19/30
# Progress: 20/30
# Progress: 21/30
# Progress: 22/30
# Progress: 23/30
# Progress: 24/30
# Progress: 25/30
# Progress: 26/30
# Progress: 27/30
# Progress: 28/30
# Progress: 29/30

# %%
df
# Out:
#                         Company Name  \
# 0                  Rakuten Kobo\n3.8
# 1                        Syniti\n3.8
# 2                     HomeStars\n3.6
# 3   Natural Partners Fullscript\n4.7
# 4            Data Sciences Inc.\n5.0
# 5                Plenty of Fish\n4.5
# 6                Intrigue Media\n4.8
# 7                     Kano/Apps\n4.0
# 8                       AltisHR\n4.0
# 9                    StackAdapt\n4.1
# 10                    Joe Fresh\n3.1
# 11                  PressReader\n3.6
# 12                    Synechron\n3.6
# 13                      Fujitsu\n3.3
# 14                     GasBuddy\n3.4
# 15               Service Canada\n3.4
# 16                     Evercore\n4.0
# 17                    Joe Fresh\n3.1
# 18                          War Room
# 19                      QSI Inc\n5.0
# 20                      flexpay\n4.4
# 21                        TEEMA\n4.7
# 22                         NCRI\n3.2
# 23                            Lucova
# 24                          RBC\n3.9
# 25                    Vantix Systems
# 26            Atlantis IT group\n3.6
# 27           Western University\n3.6
# 28                Pangea Global, LLC
# 29                  J.D. Irving\n4.3
#
#                                     Competitors Founded         Headquarters  \
# 0                        Amazon, Barnes & Noble    2009      Toronto, Canada
# 1                     Collabera, Commvault, LTI    1996          Hyannis, MA
# 2                                            -1    2006      Toronto, Canada
# 3                                            -1    2012       Ottawa, Canada
# 4                                            -1    2013           Vienna, VA
# 5                                            -1    2003    Vancouver, Canada
# 6                                            -1    2007       Guelph, Canada
# 7                                            -1    2008     Victoria, Canada
# 8                                            -1    1989       Ottawa, Canada
# 9                                            -1    2013      Toronto, Canada
# 10                                           -1    2006      Toronto, Canada
# 11                                           -1    1999     Richmond, Canada
# 12                                           -1    2001         New York, NY
# 13  Atos, Hewlett Packard Enterprise | HPE, IBM    1935     MINATO-KU, Japan
# 14                                           -1    2000           Boston, MA
# 15                                           -1      -1       Ottawa, Canada
# 16                                           -1      -1                   -1
# 17                                           -1    2006      Toronto, Canada
# 18                                           -1    2010    Vancouver, Canada
# 19                                           -1    1989       Ottawa, Canada
# 20                                           -1    2011     Montreal, Canada
# 21                                           -1    2008  Litchfield Park, AZ
# 22                                           -1      -1  Mississauga, Canada
# 23                                           -1      -1      Toronto, Canada
# 24                 Barclays, Morgan Stanley, TD    1869      Toronto, Canada
# 25                                           -1      -1     Edmonton, Canada
# 26                                           -1    2007         Somerset, NJ
# 27                                           -1    1863       London, Canada
# 28                                           -1      -1      Calgary, Canada
# 29                                           -1    1882   Saint John, Canada
#
#                                    Industry  \
# 0        Media & Entertainment Retail Shops
# 1                               IT Services
# 2   Enterprise Software & Network Solutions
# 3                                  Internet
# 4                 Biotech & Pharmaceuticals
# 5                                  Internet
# 6                   Advertising & Marketing
# 7                                        -1
# 8                    Staffing & Outsourcing
# 9                   Advertising & Marketing
# 10       Department, Clothing, & Shoe Shops
# 11                               Publishing
# 12                              IT Services
# 13                                       -1
# 14                       Oil & Gas Services
# 15                 Health, Beauty & Fitness
# 16                                       -1
# 17       Department, Clothing, & Shoe Shops
# 18                  Advertising & Marketing
# 19                               Consulting
# 20  Enterprise Software & Network Solutions
# 21                   Staffing & Outsourcing
# 22    Investment Banking & Asset Management
# 23                                       -1
# 24               Banks & Building Societies
# 25                                       -1
# 26                              IT Services
# 27                  Colleges & Universities
# 28                                       -1
# 29                 Industrial Manufacturing
#
#                                       Job Description  \
# 0   Job Description:\nDataAnalyst, Finance\nHere a...
# 1   Syniti, formerly BackOffice Associates, was fo...
# 2   WHO WE ARE:\n\nHomeowners invest their time, m...
# 3   Fullscript is currently seeking a Sales Data A...
# 4   Job Description\nWe're looking for someone to ...
# 5   We are looking for a Senior Data Analyst to be...
# 6   At Intrigue, our purpose is empowering leaders...
# 7   Kano is looking for a Data Analyst to help us ...
# 8   Our client in the risk and compliance industry...
# 9   StackAdapt is a self-serve programmatic advert...
# 10  Location:\n\n1 Presidents Choice Circle, Bramp...
# 11  As a Data Analyst at PressReader you will help...
# 12  Business Consulting\nData Quality Analyst\nTor...
# 13  Fujitsu Canada has an exciting opportunity for...
# 14  Data Analyst\nFull-Time | Engineering | Regina...
# 15  Job Description\n\nA Division within Service C...
# 16  Founded over the fall of 2016 by Tech Entrepre...
# 17  Location:\n\n1 Presidents Choice Circle, Bramp...
# 18  WHO YOU ARE\nYou love data, and you understand...
# 19  Job Description\n\nTranslate Business rules to...
# 20  Employment Terms: Full-time\n\nReports To: Dir...
# 21  Job Description\nTitle: Data Analyst\nJob ID: ...
# 22  Who Are We?\n\nAt National Credit Recovery Inc...
# 23  About Nōwn\nNōwn POS is the all-in-one custome...
# 24  What is the opportunity?\nAre you interested i...
# 25  Please contact human resources if you have any...
# 26  Data Scientist Analyst.\nCredit scorecard mode...
# 27  About Western\n\nSince 1878, Western Universit...
# 28  Location: Calgary, AB\nOpenings: 1\n\nSalary R...
# 29  DATA ANALYST - ADVANCED ANALYTICS\n\nJDI Finan...
#
#                                       Job Title     Location Rating  \
# 0                                  Data Analyst      Toronto    3.8
# 1                                  Data Analyst      Moncton    3.8
# 2                          Product Data Analyst      Toronto    3.6
# 3                            Sales Data Analyst       Ottawa    4.7
# 4                                  Data Analyst     Montreal    5.0
# 5                           Senior Data Analyst    Vancouver    4.5
# 6         Data Analyst and Reporting Specialist       Guelph    4.8
# 7                           Junior Data Analyst     Victoria    4.0
# 8             Entry level Data Analyst Contract    Vancouver    4.0
# 9                  Data Analyst/Sr Data Analyst      Toronto    4.1
# 10                         Data Science Analyst     Brampton    3.1
# 11                                 Data Analyst     Richmond    3.6
# 12                         Data Quality Analyst      Toronto    3.6
# 13                                 Data Analyst       Ottawa    3.3
# 14                                 Data Analyst       Regina    3.4
# 15                              Jr Data Analyst       Ottawa    3.4
# 16                                 Data Analyst     Montreal    4.0
# 17          Analyst, Data, Insights & Analytics     Brampton    3.1
# 18                     Data & Reporting Analyst    Vancouver     -1
# 19                                 Data Analyst       Ottawa    5.0
# 20                        Business Data Analyst     Montreal    4.4
# 21                                 Data Analyst      Burnaby    4.7
# 22                                 Data Analyst  Mississauga    3.2
# 23                                 Data Analyst      Toronto     -1
# 24  Data Analyst, Fall 2020 Co-op Opportunities      Toronto    3.9
# 25                                 Data-Analyst      Calgary     -1
# 26                       Data Scientist Analyst      Toronto    3.6
# 27                                 Data Analyst       London    3.6
# 28                       Data Analyst/Developer      Calgary     -1
# 29            Data Analyst - Advanced Analytics   Saint John    4.3
#
#                        Revenue                 Salary Estimate  \
# 0   $100 to $500 million (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 1   $100 to $500 million (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 2     Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 3     Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 4     Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 5     Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 6       $1 to $5 million (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 7     Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 8   $100 to $500 million (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 9     Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 10    Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 11    Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 12  $100 to $500 million (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 13          $10+ billion (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 14    Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 15    Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 16    Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 17    Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 18    Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 19    $10 to $25 million (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 20    Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 21  $100 to $500 million (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 22      $1 to $5 million (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 23    Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 24          $10+ billion (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 25      $1 to $5 million (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 26      $1 to $5 million (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 27    $10 to $25 million (CAD)  CA$49k-CA$66k (Glassdoor Est.)
# 28    Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
# 29    Unknown / Non-Applicable  CA$49k-CA$66k (Glassdoor Est.)
#
#                           Sector                     Size  \
# 0                         Retail     201 to 500 employees
# 1         Information Technology    501 to 1000 employees
# 2         Information Technology      51 to 200 employees
# 3         Information Technology     201 to 500 employees
# 4      Biotech & Pharmaceuticals        1 to 50 employees
# 5         Information Technology      51 to 200 employees
# 6              Business Services        1 to 50 employees
# 7                             -1        1 to 50 employees
# 8              Business Services      51 to 200 employees
# 9              Business Services      51 to 200 employees
# 10                        Retail     201 to 500 employees
# 11                         Media      51 to 200 employees
# 12        Information Technology  5001 to 10000 employees
# 13                            -1         10000+ employees
# 14  Oil, Gas, Energy & Utilities      51 to 200 employees
# 15             Consumer Services        1 to 50 employees
# 16                            -1                  Unknown
# 17                        Retail     201 to 500 employees
# 18             Business Services        1 to 50 employees
# 19             Business Services        1 to 50 employees
# 20        Information Technology        1 to 50 employees
# 21             Business Services     201 to 500 employees
# 22                       Finance        1 to 50 employees
# 23                            -1        1 to 50 employees
# 24                       Finance         10000+ employees
# 25                            -1        1 to 50 employees
# 26        Information Technology        1 to 50 employees
# 27                     Education      51 to 200 employees
# 28                            -1                  Unknown
# 29                 Manufacturing         10000+ employees
#
#                  Type of ownership
# 0                Company - Private
# 1                Company - Private
# 2   Subsidiary or Business Segment
# 3                Company - Private
# 4                Company - Private
# 5                 Company - Public
# 6                Company - Private
# 7                Company - Private
# 8                Company - Private
# 9                Company - Private
# 10  Subsidiary or Business Segment
# 11               Company - Private
# 12               Company - Private
# 13                Company - Public
# 14               Company - Private
# 15                      Government
# 16               Company - Private
# 17  Subsidiary or Business Segment
# 18               Company - Private
# 19               Company - Private
# 20               Company - Private
# 21               Company - Private
# 22               Company - Private
# 23                Company - Public
# 24                Company - Public
# 25               Company - Private
# 26               Company - Private
# 27            College / University
# 28               Company - Private
# 29               Company - Private
